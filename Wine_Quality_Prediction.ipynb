# %% [markdown]
# <a href="https://colab.research.google.com/github/hiteshnagar2611/Legacy_ML_Projects/blob/main/Wine_Quality_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection

# %%
# loading the dataset to a pandas dataframe
wine_dataset = pd.read_csv('/content/WineQT.csv')

# %%
# number of row and columns in datset
wine_dataset.shape
# Out:
# (1143, 13)

# %%
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  Id
# 0            7.4              0.70         0.00  ...      9.4        5   0
# 1            7.8              0.88         0.00  ...      9.8        5   1
# 2            7.8              0.76         0.04  ...      9.8        5   2
# 3           11.2              0.28         0.56  ...      9.8        6   3
# 4            7.4              0.70         0.00  ...      9.4        5   4
#
# [5 rows x 13 columns]

# %%
# cheking missing values in dataset
wine_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %% [markdown]
# Data Analysis and Visulaization

# %%
# statical measures of the dataset
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  ...      quality           Id
# count    1143.000000       1143.000000  ...  1143.000000  1143.000000
# mean        8.311111          0.531339  ...     5.657043   804.969379
# std         1.747595          0.179633  ...     0.805824   463.997116
# min         4.600000          0.120000  ...     3.000000     0.000000
# 25%         7.100000          0.392500  ...     5.000000   411.000000
# 50%         7.900000          0.520000  ...     6.000000   794.000000
# 75%         9.100000          0.640000  ...     6.000000  1209.500000
# max        15.900000          1.580000  ...     8.000000  1597.000000
#
# [8 rows x 13 columns]

# %%
# number of values for each quality
sns.catplot(x='quality', data = wine_dataset, kind = 'count')

# %%
# volatile acidity vs quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y='volatile acidity', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# Correlation

# %%
correlation = wine_dataset.corr()

# %%
# constructing the heat map to understand correlation
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot= True, annot_kws={'size':8}, cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# Data Preprosessing

# %%
# seprate data and Label
x = wine_dataset.drop('quality', axis = 1)

# %%
# bainarization of Labels(Label Encoding)
y = wine_dataset['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1138    0
# 1139    0
# 1140    0
# 1141    0
# 1142    0
# Name: quality, Length: 1143, dtype: int64

# %% [markdown]
# Tarin & Test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state= 2)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (1143,) (914,) (229,)

# %% [markdown]
# Model Traing (Randome Forest clasifier)

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on test data
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy :', test_data_accuracy)
# Out:
# Accuracy : 0.9126637554585153

# %% [markdown]
# Bulding the predictive system

# %%
input_data = (7.8,0.88,0.0,2.6,0.098,25.0,67.0,0.9968,3.2,0.68,9.8,1)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array as we are predictiong for only one label
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if(prediction[0] == 1):
  print('Good Quality wine')
else:
  print('Bad Quality wine')
# Out:
# [0]
# Bad Quality wine
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
